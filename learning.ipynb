# %%
import torch.nn as nn
import cv2
import torch
import numpy as np

# %%
img=cv2.imread(r"E:\SHI\YOLO_V3\model_data\images\birds_5.jpg")
img=np.array(img)
type(img)
# Out:
# numpy.ndarray

# %%
input=np.expand_dims(img, axis=0)
input.shape
img=np.array(img)
type(img)
# Out:
# numpy.ndarray

# %%
y=torch.from_numpy(input)
type(y)
# Out:
# torch.Tensor

# %%
m = nn.Conv2d(3, 33, 3, stride=1,bias=True)
output = m(y)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16336\3444028675.py in <module>
#       1 m = nn.Conv2d(3, 33, 3, stride=1,bias=True)
# ----> 2 output = m(y)
#
# c:\users\abi78\appdata\local\programs\python\python37\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\abi78\appdata\local\programs\python\python37\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     461
# ...

# %%
m = nn.Conv2d(3, 33, 3, stride=2)
 # non-square kernels and unequal stride and with padding
m = nn.Conv2d(3, 33, (3, 5), stride=(2, 1), padding=(4, 2))
# non-square kernels and unequal stride and with padding and dilation
m = nn.Conv2d(3, 33, (3, 5), stride=(2, 1), padding=(4, 2), dilation=(3, 1))
input = torch.randn(20, 3, 50, 100)
output = m(input)
output.shape
# Out:
# torch.Size([20, 33, 26, 100])

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
 
# Read Images
img = mpimg.imread(r"E:\SHI\YOLO_V3\model_data\images\birds_5.jpg")
 
# Output Images
plt.imshow(img)
